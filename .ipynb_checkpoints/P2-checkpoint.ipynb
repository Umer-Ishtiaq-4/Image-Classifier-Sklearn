# %%
import numpy as np
import pandas as pd

# %%
Xtr=np.loadtxt("TrainData.csv")
Ytr=np.loadtxt("TrainLabels.csv")
Xts=np.loadtxt("TestData.csv")

# %%
import matplotlib.pyplot as plt
plt.imshow(Xtr[10].reshape([28,28]))

# %%
# Not required
from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.feature import hog
from skimage import exposure
import matplotlib.pyplot as plt

# %%
from skimage import data,color,feature
import skimage.data

# %%
image = color.rgb2gray(data.chelsea())
print(image)
hog_vec,hog_vis = feature.hog(image,visualize= True)
print(hog_vec)
fig, ax = plt.subplots(1,2,figsize=(12,6),subplot_kw=dict(xticks=[], yticks=[]))
ax[0].imshow(image, cmap='gray')
ax[0].set_title('input image')

ax[1].imshow(hog_vis)
ax[1].set_title('Hog features')
# Out:
# [[0.48523098 0.48523098 0.47738784 ... 0.11692392 0.11692392 0.11692392]
#  [0.49699569 0.49307412 0.48523098 ... 0.12336824 0.1225349  0.1272898 ]
#  [0.50849255 0.50457098 0.49475569 ... 0.12336039 0.12728196 0.13120353]
#  ...
#  [0.24786745 0.29884784 0.40501294 ... 0.58914824 0.58914824 0.58914824]
#  [0.38173647 0.42487373 0.39628392 ... 0.57403529 0.57403529 0.57795686]
#  [0.42487373 0.36883294 0.36042431 ... 0.55442745 0.55442745 0.55834902]]
# [0.02976316 0.         0.         ... 0.00032657 0.         0.        ]
# Text(0.5, 1.0, 'Hog features')

# %%
hog_vec
# Out:
# array([0.02976316, 0.        , 0.        , ..., 0.00032657, 0.        ,
#        0.        ])

# %%
### staring
import matplotlib.pyplot as plt

# %%
Xtr=np.loadtxt("TrainData.csv")
Ytr=np.loadtxt("TrainLabels.csv")
Xts=np.loadtxt("TestData.csv")

# %%
print(len(Xtr[0]))
# Out:
# 784

# %% [markdown]
# ## Step 1

# %%
## Loading Image

# %matplotlib inline

#reading the image
img = imread('flower.jpg')
imshow(img)
print(img.shape)
# Out:
# (3329, 2497, 3)

# %%
## Extracting Hog Features
fd, hog_image = hog(img, orientations=9, pixels_per_cell=(8, 8), cells_per_block=(2, 2), visualize=True, multichannel=True)

# %% [markdown]
# ## Step 2

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6), sharex=True, sharey=True) 

ax1.imshow(img, cmap=plt.cm.gray) 
ax1.set_title('Input image') 

# Rescale histogram for better display 
hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 10)) 

ax2.imshow(hog_image_rescaled, cmap=plt.cm.gray) 
ax2.set_title('Histogram of Oriented Gradients')
plt.show()

# %% [markdown]
# ## Step 3

# %%
plt.imshow(Xtr[2656].reshape([28,28]))
#plt.savefig('shirt.jpg')
plt.show()

# %% [markdown]
# ## Step 4

# %%
#plt.imshow(Xtr[10].reshape([28,28]))
shirt =Xtr[10].reshape([28,28])
## Extracting Hog Features
fd, shirt_img = hog(shirt, orientations=8, pixels_per_cell=(4, 4),cells_per_block=(1, 1), visualize=True, multichannel=None)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8,4), sharex=True, sharey=True) 

ax1.axis('off')
ax1.imshow(shirt, cmap=plt.cm.gray) 
ax1.set_title('Input image') 

# Rescale histogram for better display 
hog_image_rescaled = exposure.rescale_intensity(shirt_img, in_range=(0, 10))
ax2.axis('off')
ax2.imshow(hog_image_rescaled, cmap=plt.cm.gray) 
ax2.set_title('Histogram of Oriented Gradients')
plt.show()

# %%
print(Ytr[11])
print(len(fd))
# Out:
# 1.0
# 392

# %% [markdown]
# ## Step 5

# %%
def Extract(shirt):
    fd, shirt_img = hog(shirt, orientations=8, pixels_per_cell=(4, 4),cells_per_block=(1, 1), visualize=True, multichannel=None)
    #fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8,4), sharex=True, sharey=True) 
    return fd
    #ax1.axis('off')
    #ax1.imshow(shirt, cmap=plt.cm.gray) 
    #ax1.set_title('Input image') 

    # Rescale histogram for better display 
#     hog_image_rescaled = exposure.rescale_intensity(shirt_img, in_range=(0, 10))
#     ax2.axis('off')
#     ax2.imshow(hog_image_rescaled, cmap=plt.cm.gray) 
#     ax2.set_title('Histogram of Oriented Gradients')
#     plt.show()

# %%
x_train = []
Y_train = []
for i in range(len(Xtr)):
    #X_feature = Xtr[i]
    X_feature = Extract(Xtr[i].reshape([28,28]))
    x_train.append(X_feature)
    Y_train.append(Ytr[i])

# %%
li = [1,3,5,6,7,8]
np.array(li[:4])
# Out:
# array([1, 3, 5, 6])

# %%
print(len(x_train))
print(len(Y_train))
x_train = np.array(x_train[:3000])
y_feat = np.array(Y_train[:3000])
# Out:
# 3000
# 12000

# %%
print(len(x_train))
print(type(y_feat))
# Out:
# 3000
# <class 'numpy.ndarray'>

# %% [markdown]
# ## Cross Validation Score

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'linear', random_state = 0)

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(classifier,x_train,y_feat,cv=5)
# Out:
# array([0.85666667, 0.82833333, 0.82166667, 0.81833333, 0.825     ])

# %%
from sklearn.tree import DecisionTreeClassifier 
clf = DecisionTreeClassifier()

# %%
cross_val_score(clf,x_train,y_feat,cv=5)
# Out:
# array([0.74833333, 0.77833333, 0.75333333, 0.74666667, 0.73      ])

# %%
print(len(x_train[0]))
print(len(y_train))

# %% [markdown]
# ## Step 6

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_train, y_train, test_size = 0.20, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'linear', random_state = 0)
classifier.fit(X_train, y_train)

# Predicti ng the Test set results
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[1139  331]
#  [ 264 1266]]

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)*100
# Out:
# 80.20833333333334

# %%
print(len(X_train))
# Out:
# 9600
